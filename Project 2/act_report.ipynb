# %% [markdown]
# # WeRateDogs

# %% [markdown]
# ## Introduction

# %% [markdown]
# <a href = https://twitter.com/dog_rates>WeRateDogs</a> is a Twitter account that rates people's dogs with a humorous comment
# about the dog. These ratings almost always have a denominator of 10. However, the numerators are almost always greater than 10. (11/10, 12/10, 13/10, etc.) Why? Because "they're good dogs Brent."
#
# WeRateDogs has over 4 million followers and has received international media coverage. So, what to do with these ratings? With dogs the best common question has to be which is the most popular dog? Can we get any relationship between Retweets, Favorites and Ratings? I have wrangled the WeRateDogs twitter data and have analyzed it to get answers of these questions.

# %% [markdown]
# ## Analysis

# %% [markdown]
# Overall, WeRateDogs has over 2000 retweets and about 8000 likes on average at the time that the data was scraped. This indicates how interactive their posts are.
#
# The analysis also shows that there is a correlation between retweet and favorite counts as depicted in the plot below.

# %% [markdown]
# ![figure1.png](attachment:figure1.png)

# %% [markdown]
# The dogs were grouped into four stages; doggo, floofer, pupper and puppo. Of the stages, floofer and puppo have the highest retweet and favourite counts. They are also the most rated dogs.

# %% [markdown]
# Furthermore, people engage most with WeRateDog posts on saturdays as indicated by days that have the highest retweet and favourite counts.

# %% [markdown]
# ![figure2.png](attachment:figure2.png)

# %% [markdown]
# ![figure3.png](attachment:figure3.png)

# %% [markdown]
# Ratings are not really influenced by weekdays. However on Monday, the ratings were higher than other days. Further analysis shows that a dog was rated 1776/10 on monday. The picture of the dog is shown below

# %% [markdown]
# ![funny_dog.jpg](attachment:funny_dog.jpg)

# %% [markdown]
# A word cloud of the tweets is shown below:

# %% [markdown]
# ![figure5.png](attachment:figure5.png)

# %% [markdown]
# ![cute.jpg](attachment:cute.jpg)
